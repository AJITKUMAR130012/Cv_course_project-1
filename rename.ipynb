# %%
import os
os.getcwd()
collection = "./Yogeshwer"
for i, filename in enumerate(os.listdir(collection)):
   # if filename.split('.')[-1]=="bmp":
        os.rename(collection+"/"+filename,collection+"_"+str(i)+ ".jpg")
